# %%
# 导入必须的库
import numpy as np
import pandas as pd
from time import time
from IPython.display import display
# import pandas_profiling

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %matplotlib inline

# 导入数据
data_train = pd.read_csv("train.csv")
data_store = pd.read_csv("store.csv")
data_test = pd.read_csv("test.csv")

# 显示第一条记录
display(data_train.head())
# Out:
# C:\Users\taili\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
#Store处理
#Null值处理
data_store['PromoInterval'].fillna('',inplace=True)

# %%
#Null值处理
data_store['Promo2SinceWeek'].fillna(0,inplace=True)
data_store['Promo2SinceYear'].fillna(0,inplace=True)
data_store['CompetitionDistance'].fillna(-1,inplace=True)

# %%
import sqlite3
conn = sqlite3.connect('raw_data.db')
c = conn.cursor()

#定义sql执行函数
def exe_sql(sql):
    c.execute(sql)

# %%
#导入本地sqlite
data_train.to_sql('train_data', conn, if_exists='replace', index=False)
data_store.to_sql('store', conn, if_exists='replace', index=False)
data_test.to_sql('test_data', conn, if_exists='replace', index=False)

# %%
#store表与train表，store表月test表拼合

#丢弃拼合数据表_训练集
exe_sql("drop table if exists train_data_union")

#执行拼合
exe_sql("create table train_data_union as select t1.*,StoreType,Assortment,CompetitionDistance,CompetitionOpenSinceMonth,CompetitionOpenSinceYear,Promo2,Promo2SinceWeek,Promo2SinceYear,PromoInterval from train_data t1 left outer join store t2 on t1.Store=t2.Store")

#丢弃拼合数据表_测试集
exe_sql("drop table if exists test_data_union")

#执行拼合
exe_sql("create table test_data_union as select t1.*,StoreType,Assortment,CompetitionDistance,CompetitionOpenSinceMonth,CompetitionOpenSinceYear,Promo2,Promo2SinceWeek,Promo2SinceYear,PromoInterval from test_data t1 left outer join store t2 on t1.Store=t2.Store")

# %%
#特征抽取
exe_sql("drop table if exists train_data_set")
exe_sql("create table train_data_set as SELECT Store,DayOfWeek,Date,substr(Date,1,4) as year,substr(Date,6,2) as month,substr(Date,9,2) as day,Sales,Customers,Open,Promo,StateHoliday,SchoolHoliday,StoreType,Assortment,CompetitionDistance,case when (substr(Date,1,4)-CompetitionOpenSinceYear)*365>=0 then (substr(Date,1,4)-CompetitionOpenSinceYear)*365+(substr(Date,6,2)-CompetitionOpenSinceMonth)*30 else -1 end as Competition_days,Promo2,Promo2SinceWeek,Promo2SinceYear,PromoInterval FROM train_data_union")

#特征抽取
exe_sql("drop table if exists test_data_set")
exe_sql("create table test_data_set as SELECT Id,Store,DayOfWeek,Date,substr(Date,1,4) as year,substr(Date,6,2) as month,substr(Date,9,2) as day,Open,Promo,StateHoliday,SchoolHoliday,StoreType,Assortment,CompetitionDistance,case when (substr(Date,1,4)-CompetitionOpenSinceYear)*365>=0 then (substr(Date,1,4)-CompetitionOpenSinceYear)*365+(substr(Date,6,2)-CompetitionOpenSinceMonth)*30 else -1 end as Competition_days,Promo2,Promo2SinceWeek,Promo2SinceYear,PromoInterval FROM test_data_union")

# %%
data_train_set = pd.read_sql("select * from train_data_set",conn)
test_train_set = pd.read_sql("select * from test_data_set",conn)

# %%
data_train_set.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday  CompetitionDistance  Competition_days  \
# count  1.017209e+06   1.017209e+06         1.017209e+06      1.017209e+06
# mean   3.815145e-01   1.786467e-01         5.415979e+03      1.274753e+03
# std    4.857586e-01   3.830564e-01         7.710255e+03      1.990654e+03
# min    0.000000e+00   0.000000e+00        -1.000000e+00     -3.300000e+02
# 25%    0.000000e+00   0.000000e+00         7.000000e+02     -1.000000e+00
# 50%    0.000000e+00   0.000000e+00         2.320000e+03      4.900000e+02
# 75%    1.000000e+00   0.000000e+00         6.880000e+03      2.220000e+03
# max    1.000000e+00   1.000000e+00         7.586000e+04      4.215500e+04
#
#              Promo2  Promo2SinceWeek  Promo2SinceYear
# count  1.017209e+06     1.017209e+06     1.017209e+06
# mean   5.005638e-01     1.164767e+01     1.007011e+03
# std    4.999999e-01     1.532393e+01     1.005877e+03
# min    0.000000e+00     0.000000e+00     0.000000e+00
# 25%    0.000000e+00     0.000000e+00     0.000000e+00
# 50%    1.000000e+00     1.000000e+00     2.009000e+03
# 75%    1.000000e+00     2.200000e+01     2.012000e+03
# max    1.000000e+00     5.000000e+01     2.015000e+03

# %%
data_train_set.head()
# Out:
#    Store  DayOfWeek        Date  year month day  Sales  Customers  Open  \
# 0      1          5  2015-07-31  2015    07  31   5263        555     1
# 1      2          5  2015-07-31  2015    07  31   6064        625     1
# 2      3          5  2015-07-31  2015    07  31   8314        821     1
# 3      4          5  2015-07-31  2015    07  31  13995       1498     1
# 4      5          5  2015-07-31  2015    07  31   4822        559     1
#
#    Promo StateHoliday  SchoolHoliday StoreType Assortment  \
# 0      1            0              1         c          a
# 1      1            0              1         a          a
# 2      1            0              1         a          a
# 3      1            0              1         c          c
# 4      1            0              1         a          a
#
#    CompetitionDistance  Competition_days  Promo2  Promo2SinceWeek  \
# 0               1270.0            2495.0       0              0.0
# 1                570.0            2800.0       1             13.0
# 2              14130.0            3135.0       1             14.0
# 3                620.0            2130.0       0              0.0
# 4              29910.0              90.0       0              0.0
#
#    Promo2SinceYear    PromoInterval
# 0              0.0
# 1           2010.0  Jan,Apr,Jul,Oct
# 2           2011.0  Jan,Apr,Jul,Oct
# 3              0.0
# 4              0.0

# %%
#映射编码
mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
data_train_set.StoreType.replace(mappings, inplace=True)
data_train_set.Assortment.replace(mappings, inplace=True)
data_train_set.StateHoliday.replace(mappings, inplace=True)

# %%
#类型转化
data_train_set['year'] = data_train_set['year'].astype('int')
data_train_set['month'] = data_train_set['month'].astype('int')
data_train_set['day'] = data_train_set['day'].astype('int')
data_train_set['StateHoliday'] = data_train_set['StateHoliday'].astype('int')
data_train_set['Assortment'] = data_train_set['Assortment'].astype('int')
data_train_set['StoreType'] = data_train_set['Assortment'].astype('int')

# %%
#促销月份
month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun',7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
data_train_set['month_str'] = data_train_set.month.map(month2str)
def check(row):
    if isinstance(row['PromoInterval'],str) and row['month_str'] in row['PromoInterval']:
        return 1
    else:
        return 0
        
data_train_set['IsPromoMonth'] =  data_train_set.apply(lambda row: check(row),axis=1)
mappings_promo = {'':0, 'Jan,Apr,Jul,Oct':1, 'Feb,May,Aug,Nov':2, 'Mar,Jun,Sept,Dec':3}
data_train_set['PromoInterval'] = data_train_set.PromoInterval.map(mappings_promo)

# %%
data_train_set.head()
# Out:
#    Store  DayOfWeek        Date  year  month  day  Sales  Customers  Open  \
# 0      1          5  2015-07-31  2015      7   31   5263        555     1
# 1      2          5  2015-07-31  2015      7   31   6064        625     1
# 2      3          5  2015-07-31  2015      7   31   8314        821     1
# 3      4          5  2015-07-31  2015      7   31  13995       1498     1
# 4      5          5  2015-07-31  2015      7   31   4822        559     1
#
#    Promo  ...  StoreType  Assortment  CompetitionDistance  Competition_days  \
# 0      1  ...          1           1               1270.0            2495.0
# 1      1  ...          1           1                570.0            2800.0
# 2      1  ...          1           1              14130.0            3135.0
# 3      1  ...          3           3                620.0            2130.0
# 4      1  ...          1           1              29910.0              90.0
#
#    Promo2  Promo2SinceWeek  Promo2SinceYear  PromoInterval  month_str  \
# 0       0              0.0              0.0              0        Jul
# 1       1             13.0           2010.0              1        Jul
# 2       1             14.0           2011.0              1        Jul
# 3       0              0.0              0.0              0        Jul
# 4       0              0.0              0.0              0        Jul
#
#    IsPromoMonth
# 0             0
# 1             1
# 2             1
# 3             0
# 4             0
#
# [5 rows x 22 columns]

# %%
#训练集与验证集分离
data_train_set = data_train_set.sort_values(['Date'],ascending = False)
train_total = data_train_set.copy()

# %%
#分离
split_index = 6*7*1115
valid = data_train_set[:split_index] 
train = data_train_set[split_index:]

# %%
#丢弃无用数据
valid = valid[(valid.Open != 0)&(valid.Sales >0)]
train = train[(train.Open != 0)&(train.Sales >0)]
train_total = train_total[(train_total.Open != 0)&(train_total.Sales >0)]

# %%
#Drop_list
drop_list = ['Sales','Date','month_str','Customers']

# %%
#训练集拆分
# from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train.drop(drop_list,axis=1),valid.drop(drop_list,axis=1),train['Sales'],valid['Sales']

# %%
X_train.head()
# Out:
#        Store  DayOfWeek  year  month  day  Open  Promo  StateHoliday  \
# 47570    741          5  2015      6   19     1      1             0
# 47576    747          5  2015      6   19     1      1             0
# 47575    746          5  2015      6   19     1      1             0
# 47574    745          5  2015      6   19     1      1             0
# 47573    744          5  2015      6   19     1      1             0
#
#        SchoolHoliday  StoreType  Assortment  CompetitionDistance  \
# 47570              0          3           3              11900.0
# 47576              0          3           3              45740.0
# 47575              0          3           3               4330.0
# 47574              0          1           1              17650.0
# 47573              0          1           1               1370.0
#
#        Competition_days  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 47570              -1.0       0              0.0              0.0
# 47576            2495.0       0              0.0              0.0
# 47575            1580.0       1             35.0           2011.0
# 47574             580.0       1             37.0           2009.0
# 47573            1280.0       1             40.0           2014.0
#
#        PromoInterval  IsPromoMonth
# 47570              0             0
# 47576              0             0
# 47575              3             1
# 47574              1             0
# 47573              1             0

# %%
X_train.dtypes
# Out:
# Store                    int64
# DayOfWeek                int64
# year                     int32
# month                    int32
# day                      int32
# Open                     int64
# Promo                    int64
# StateHoliday             int32
# SchoolHoliday            int64
# StoreType                int32
# Assortment               int32
# CompetitionDistance    float64
# Competition_days       float64
# Promo2                   int64
# Promo2SinceWeek        float64
# Promo2SinceYear        float64
# PromoInterval            int64
# IsPromoMonth             int64
# dtype: object

# %%
X_train.isnull().sum()
# Out:
# Store                  0
# DayOfWeek              0
# year                   0
# month                  0
# day                    0
# Open                   0
# Promo                  0
# StateHoliday           0
# SchoolHoliday          0
# StoreType              0
# Assortment             0
# CompetitionDistance    0
# Competition_days       0
# Promo2                 0
# Promo2SinceWeek        0
# Promo2SinceYear        0
# PromoInterval          0
# IsPromoMonth           0
# dtype: int64

# %%
y_train.head()
# Out:
# 47570    7329
# 47576    9367
# 47575    7856
# 47574    8074
# 47573    8626
# Name: Sales, dtype: int64

# %%
#xgboost训练集与验证集重组
X_train['target'] = y_train
X_test['target'] = y_test
train_data_set = [X_train, X_test]

# %%
#估计函数
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV

#初始参数
param_init = {'learning_rate':0.1,
              'max_depth':5,
              'n_estimators':100,
              'min_child_weight':1,
              'gamma':0,
              'subsample':0.8,
              'colsample_bytree':0.8,
              'objective':'reg:squarederror',
              'scale_pos_weight':1,
              'seed':27
}

# %%
#定义评估函数
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    #y = np.expm1(y.get_label())
    #yhat = np.expm1(yhat)
    return "rmspe", rmspe(y.get_label(),yhat)

rmspe_score = make_scorer(rmspe,  greater_is_better=False)

# %%
#函数初始化
def modelfit(alg, i,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    param_test = {'n_estimators':[500]}
    if useTrainCV:
        xgb_param = param_init
        xgtrain = xgb.DMatrix(i[0].drop(['target'],axis = 1), label=i[0]['target'])
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,
                          feval=rmspe_xg, early_stopping_rounds=early_stopping_rounds,verbose_eval=False)
        alg.set_params(n_estimators=cvresult.shape[0])

    #Fit the algorithm on the data
    print(alg.get_params())
    gsearch_rmspe = GridSearchCV(estimator = alg,
                           param_grid = param_test,
                           scoring=rmspe_score,
                           n_jobs=-1,
                           iid=False,
                           cv=5)

    gsearch_rmspe.fit(i[0].drop(['target'],axis = 1), i[0]['target'],eval_metric=rmspe_xg)

    #Print model report:
    print("\nModel Report")
    print('RMSPE: {:.4f}'.format(gsearch_rmspe.best_score_))
    
    best_alg = gsearch_rmspe.best_estimator_

    feat_imp = pd.Series(best_alg.get_booster().get_fscore()).sort_values(ascending=False)
    feat_imp.plot(kind='bar', title='Feature Importances')

    return best_alg

def gridsearch_xg(i, param_init_d, param_test_d):
    print(param_init_d)
    print(param_test_d)
    gsearch = GridSearchCV(estimator = XGBRegressor(**param_init_d),param_grid = param_test_d,scoring=rmspe_score,n_jobs=-1,iid=False,cv=5)
    gsearch.fit(i[0].drop(['target'],axis = 1), i[0]['target'],eval_metric=rmspe_xg)
    print(gsearch.best_params_,gsearch.best_score_)

# %%
#参数测试
modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=True)
# Out:
# [20:17:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:17:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# {'base_score': 0.5, 'booster': 'gbtree', 'colsample_bylevel': 1, 'colsample_bynode': 1, 'colsample_bytree': 0.8, 'gamma': 0, 'importance_type': 'gain', 'learning_rate': 0.1, 'max_delta_step': 0, 'max_depth': 5, 'min_child_weight': 1, 'missing': None, 'n_estimators': 100, 'n_jobs': 1, 'nthread': None, 'objective': 'reg:linear', 'random_state': 0, 'reg_alpha': 0, 'reg_lambda': 1, 'scale_pos_weight': 1, 'seed': 27, 'silent': None, 'subsample': 0.8, 'verbosity': 1}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-7d9b42647e3b> in <module>
#       1 #参数测试
# ----> 2 modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=True)
#
# <ipython-input-35-bfa6c9fad9a5> in modelfit(alg, i, useTrainCV, cv_folds, early_stopping_rounds)
#      18                            cv=5)
#      19
# ---> 20     gsearch_rmspe.fit(i[0].drop(['target'],axis = 1), i[0]['target'],eval_metric=rmspe_xg)
#      21
#      22     #Print model report:
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     650         X, y, groups = indexable(X, y, groups)
#     651         # make sure fit_params are sliceable
# --> 652         fit_params_values = indexable(*fit_params.values())
#     653         fit_params = dict(zip(fit_params.keys(), fit_params_values))
#     654
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     235         else:
#     236             result.append(np.array(X))
# --> 237     check_consistent_length(*result)
#     238     return result
#     239
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     206     """
#     207
# --> 208     lengths = [_num_samples(X) for X in arrays if X is not None]
#     209     uniques = np.unique(lengths)
#     210     if len(uniques) > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in <listcomp>(.0)
#     206     """
#     207
# --> 208     lengths = [_num_samples(X) for X in arrays if X is not None]
#     209     uniques = np.unique(lengths)
#     210     if len(uniques) > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _num_samples(x)
#     150         if len(x.shape) == 0:
#     151             raise TypeError("Singleton array %r cannot be considered"
# --> 152                             " a valid collection." % x)
#     153         # Check that shape is returning an integer or default to len
#     154         # Dask dataframes may not return numeric shape[0] value
#
# TypeError: Singleton array array(<function rmspe_xg at 0x00000191D1B0BAF8>, dtype=object) cannot be considered a valid collection.

# %%
#网格搜索max_depth和min_child_weight
param_test = {
 'max_depth':range(3,8,1),
 'min_child_weight':range(1,6,1)
}
gridsearch_xg(train_data_set, param_init, param_test)

# %%
#更改参数
param_init['max_depth'] = 7
param_init['min_child_weight'] = 1

# %%
#参数测试
modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=False)

# %%
#网格搜索调试gamma
param_test = {
 'gamma':[i/10.0 for i in range(0,10,2)]
}
gridsearch_xg(train_data_set, param_init, param_test)

# %%
#更改参数
param_init['gamma'] = 0.8

# %%
#参数测试
modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=False)

# %%
#网格搜索调试subsample和colsample_bytree参数
param_test = {
    'subsample':[i/100.0 for i in range(60,96,5)],
    'colsample_bytree':[i/100.0 for i in range(60,96,5)]
}
gridsearch_xg(train_data_set, param_init, param_test)

# %%
#更改参数
param_init['colsample_bytree'] = 0.8
param_init['subsample'] = 0.8

# %%
#参数测试
modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=False)

# %%
#网格搜索调试正则化参数reg_alpha
param_test = {
    'reg_alpha':[1e-5, 1e-2, 0.1, 1, 100]
}
gridsearch_xg(train_data_set, param_init, param_test)

# %%
#更改参数
param_init['reg_alpha'] = 1e-05

# %%
#参数测试
modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=False)

# %%
#网格搜索调试正则化参数reg_lambda
param_test = {
    'reg_lambda':[1e-5, 1e-2, 0.1, 1, 100]
}
gridsearch_xg(train_data_set, param_init, param_test)

# %%
#更改参数
param_init['reg_lambda'] = 1

# %%
#最终模型
best_alg = modelfit(XGBRegressor(**param_init), train_data_set,useTrainCV=False)

# %%
params = {"objective": "reg:squarederror",
          "booster" : "gbtree",
          "eta": 0.03,
          "max_depth": 10,
          "subsample": 0.9,
          "colsample_bytree": 0.7,
          "silent": 1,
          "seed": 10
          }
num_boost_round = 300


dtrain = xgb.DMatrix(train_data_set[0].drop(['target'],axis = 1), label=train_data_set[0]['target'])
dvalid = xgb.DMatrix(train_data_set[1].drop(['target'],axis = 1), label=train_data_set[1]['target'])
watchlist = [(dtrain, 'train'), (dvalid, 'eval')]

#模型训练
print("Train a XGBoost model")
start = time()
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, 
  early_stopping_rounds=100, feval=rmspe_xg, verbose_eval=True)
end = time()
print('Training time is {:2f} s.'.format(end-start))
# Out:
# Train a XGBoost model
# [0]	train-rmse:7408.1	eval-rmse:7408.77	train-rmspe:0.966835	eval-rmspe:0.96738
# Multiple eval metrics have been passed: 'eval-rmspe' will be used for early stopping.
#
# Will train until eval-rmspe hasn't improved in 100 rounds.
# [1]	train-rmse:7211.21	eval-rmse:7210.48	train-rmspe:0.934417	eval-rmspe:0.935437
# [2]	train-rmse:7016.93	eval-rmse:7022.13	train-rmspe:0.903501	eval-rmspe:0.905619
# [3]	train-rmse:6830.9	eval-rmse:6834.75	train-rmspe:0.873516	eval-rmspe:0.875877
# [4]	train-rmse:6650.51	eval-rmse:6659.11	train-rmspe:0.844634	eval-rmspe:0.847783
# [5]	train-rmse:6474.73	eval-rmse:6489.33	train-rmspe:0.81699	eval-rmspe:0.821009
# [6]	train-rmse:6305.83	eval-rmse:6321.5	train-rmspe:0.790196	eval-rmspe:0.794269
# [7]	train-rmse:6144.27	eval-rmse:6158.76	train-rmspe:0.764314	eval-rmspe:0.76848
# [8]	train-rmse:5986.36	eval-rmse:5997.11	train-rmspe:0.739557	eval-rmspe:0.743558
# [9]	train-rmse:5832.68	eval-rmse:5847.83	train-rmspe:0.715852	eval-rmspe:0.720275
# [10]	train-rmse:5689.42	eval-rmse:5705.32	train-rmspe:0.692406	eval-rmspe:0.696549
# [11]	train-rmse:5543.9	eval-rmse:5564.25	train-rmspe:0.67057	eval-rmspe:0.675165
# [12]	train-rmse:5404.15	eval-rmse:5428.11	train-rmspe:0.64968	eval-rmspe:0.654458
# [13]	train-rmse:5270.65	eval-rmse:5296.31	train-rmspe:0.629198	eval-rmspe:0.633678
# [14]	train-rmse:5142.76	eval-rmse:5169.37	train-rmspe:0.60987	eval-rmspe:0.614146
# [15]	train-rmse:5015.86	eval-rmse:5041.59	train-rmspe:0.591511	eval-rmspe:0.595349
# [16]	train-rmse:4895.19	eval-rmse:4923.11	train-rmspe:0.573619	eval-rmspe:0.577133
# [17]	train-rmse:4781.35	eval-rmse:4812.23	train-rmspe:0.556665	eval-rmspe:0.559982
# [18]	train-rmse:4667.45	eval-rmse:4698.99	train-rmspe:0.540502	eval-rmspe:0.543464
# [19]	train-rmse:4560.62	eval-rmse:4591.76	train-rmspe:0.52505	eval-rmspe:0.526985
# [20]	train-rmse:4457.59	eval-rmse:4490.6	train-rmspe:0.510494	eval-rmspe:0.512107
# [21]	train-rmse:4352.31	eval-rmse:4384.98	train-rmspe:0.496467	eval-rmspe:0.497123
# [22]	train-rmse:4258.13	eval-rmse:4285.87	train-rmspe:0.483277	eval-rmspe:0.482547
# [23]	train-rmse:4161.19	eval-rmse:4189.19	train-rmspe:0.470985	eval-rmspe:0.469424
# [24]	train-rmse:4069.57	eval-rmse:4099.42	train-rmspe:0.459366	eval-rmspe:0.457071
# [25]	train-rmse:3980.55	eval-rmse:4010.7	train-rmspe:0.448377	eval-rmspe:0.444954
# [26]	train-rmse:3894.08	eval-rmse:3926.33	train-rmspe:0.437924	eval-rmspe:0.433644
# [27]	train-rmse:3813.49	eval-rmse:3841.41	train-rmspe:0.428081	eval-rmspe:0.422404
# [28]	train-rmse:3734.67	eval-rmse:3762.18	train-rmspe:0.418764	eval-rmspe:0.411943
# [140]	train-rmse:1707.23	eval-rmse:1804.21	train-rmspe:0.343017	eval-rmspe:0.317612
# [141]	train-rmse:1700.27	eval-rmse:1797.41	train-rmspe:0.342189	eval-rmspe:0.316729
# [142]	train-rmse:1693.36	eval-rmse:1789.45	train-rmspe:0.341487	eval-rmspe:0.315815
# [143]	train-rmse:1687.65	eval-rmse:1784.11	train-rmspe:0.340634	eval-rmspe:0.314902
# [144]	train-rmse:1683.52	eval-rmse:1780.45	train-rmspe:0.33976	eval-rmspe:0.314298
# [145]	train-rmse:1680.43	eval-rmse:1777.98	train-rmspe:0.339278	eval-rmspe:0.313954
# [146]	train-rmse:1672.86	eval-rmse:1770.68	train-rmspe:0.33826	eval-rmspe:0.312834
# [147]	train-rmse:1669.56	eval-rmse:1767.84	train-rmspe:0.337992	eval-rmspe:0.312594
# [148]	train-rmse:1666.49	eval-rmse:1765.04	train-rmspe:0.33785	eval-rmspe:0.312409
# [149]	train-rmse:1664.36	eval-rmse:1763.58	train-rmspe:0.337518	eval-rmspe:0.312153
# [150]	train-rmse:1661.51	eval-rmse:1761.42	train-rmspe:0.337344	eval-rmspe:0.311995
# [151]	train-rmse:1660.54	eval-rmse:1761.48	train-rmspe:0.337342	eval-rmspe:0.312216
# [152]	train-rmse:1654.11	eval-rmse:1755.65	train-rmspe:0.336771	eval-rmspe:0.311608
# [153]	train-rmse:1650.76	eval-rmse:1753.05	train-rmspe:0.336603	eval-rmspe:0.311497
# [154]	train-rmse:1645.03	eval-rmse:1748.19	train-rmspe:0.335744	eval-rmspe:0.310821
# [155]	train-rmse:1636.38	eval-rmse:1739.89	train-rmspe:0.334431	eval-rmspe:0.309352
# [156]	train-rmse:1634.34	eval-rmse:1738.06	train-rmspe:0.334349	eval-rmspe:0.309436
# [157]	train-rmse:1625.17	eval-rmse:1729.26	train-rmspe:0.332988	eval-rmspe:0.307895
# [158]	train-rmse:1620.18	eval-rmse:1724.14	train-rmspe:0.332118	eval-rmspe:0.306903
# [159]	train-rmse:1617.26	eval-rmse:1721.5	train-rmspe:0.331794	eval-rmspe:0.306592
# [160]	train-rmse:1613.37	eval-rmse:1717.12	train-rmspe:0.3314	eval-rmspe:0.306103
# [161]	train-rmse:1607.95	eval-rmse:1712.17	train-rmspe:0.330512	eval-rmspe:0.305311
# Stopping. Best iteration:
# [61]	train-rmse:2300.99	eval-rmse:2319.72	train-rmspe:0.326665	eval-rmspe:0.289675
#
# Training time is 76.452430 s.

# %%
#采用保留数据集进行检测
print("validating")
ho_xtest = train_data_set[1].drop(['target'],axis = 1)
ho_ytest = train_data_set[1]['target']
ho_xtest.sort_index(inplace=True) 
ho_ytest.sort_index(inplace=True) 
yhat = gbm.predict(xgb.DMatrix(ho_xtest))
error = rmspe(ho_ytest, yhat)

print('RMSPE: {:.6f}'.format(error))
# Out:
# validating
# RMSPE: 0.305311
